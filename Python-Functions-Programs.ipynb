# %%
#Maximum of Two Numbers
def maximum(a, b):
    if a > b:
        return a
    else:
        return b

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("Maximum =", maximum(num1, num2))
# Out:
# Enter first number:  10
# Enter second number:  5
# Maximum = 10

# %%
#Check Even or Odd
def even_odd(n):
    if n % 2 == 0:
        return "Even"
    else:
        return "Odd"

num = int(input("Enter a number: "))
print(even_odd(num))
# Out:
# Enter a number:  25
# Odd

# %%
#Factorial of a Number
def factorial(n):
    fact = 1
    for i in range(1, n + 1):
        fact *= i
    return fact

num = int(input("Enter a number: "))
print("Factorial =", factorial(num))
# Out:
# Enter a number:  5
# Factorial = 120

# %%
#Check Prime Number
def is_prime(n):
    if n <= 1:
        return "Not Prime"

    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return "Not Prime"

    return "Prime"

num = int(input("Enter a number: "))
print(is_prime(num))
# Out:
# Enter a number:  120
# Not Prime

# %%
#Reverse a String
def reverse_string(text):
    return text[::-1]

string = input("Enter a string: ")
print("Reversed String:", reverse_string(string))
# Out:
# Enter a string:  srividya
# Reversed String: aydivirs

# %%
#Count Vowels
def count_vowels(text):
    vowels = "aeiouAEIOU"
    count = 0

    for ch in text:
        if ch in vowels:
            count += 1

    return count

string = input("Enter a string: ")
print("Number of vowels:", count_vowels(string))
# Out:
# Enter a string:  srividya
# Number of vowels: 3

# %%
#Sum of List Elements
def sum_list(numbers):
    total = 0

    for i in numbers:
        total += i

    return total

numbers = list(map(int, input("Enter numbers separated by space: ").split()))

print("Sum =", sum_list(numbers))
# Out:
# Enter numbers separated by space:  1 2 3 4 5 6
# Sum = 21

# %%
#Largest Element in a List
def largest(numbers):
    large = numbers[0]

    for i in numbers:
        if i > large:
            large = i

    return large

numbers = list(map(int, input("Enter list elements: ").split()))

print("Largest =", largest(numbers))
# Out:
# Enter list elements:  12 25 8 9 78
# Largest = 78

# %%
#Check Palindrome
def palindrome(text):
    if text == text[::-1]:
        return True
    return False

word = input("Enter a string: ")

print(palindrome(word))
# Out:
# Enter a string:  madam
# True

# %%
#Fibonacci Series
def fibonacci(n):
    a = 0
    b = 1

    for i in range(n):
        print(a, end=" ")
        a, b = b, a + b

num = int(input("Enter number of terms: "))

fibonacci(num)
# Out:
# Enter number of terms:  5
# 0 1 1 2 3

# %%
#Count Words in a Sentence
def word_count(sentence):
    words = sentence.split()
    return len(words)

sentence = input("Enter a sentence: ")

print("Number of words:", word_count(sentence))
# Out:
# Enter a sentence:  hi good morning hi
# Number of words: 4

# %%
#Find GCD
def gcd(a, b):

    while b != 0:
        a, b = b, a % b

    return a

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("GCD =", gcd(num1, num2))
# Out:
# Enter first number:  52
# Enter second number:  6
# GCD = 2

# %%
#Remove Duplicates from a List
def remove_duplicates(numbers):

    result = []

    for i in numbers:
        if i not in result:
            result.append(i)

    return result

numbers = list(map(int, input("Enter list elements: ").split()))

print(remove_duplicates(numbers))
# Out:
# Enter list elements:  1 2 3 5 6 1 2 3 5
# [1, 2, 3, 5, 6]

# %%
#Simple Interest
def simple_interest(p, r, t):
    return (p * r * t) / 100

principal = float(input("Enter Principal: "))
rate = float(input("Enter Rate: "))
time = float(input("Enter Time: "))

print("Simple Interest =", simple_interest(principal, rate, time))
# Out:
# Enter Principal:  23.0
# Enter Rate:  2
# Enter Time:  12
# Simple Interest = 5.52

# %%
#Armstrong Number
def armstrong(num):

    digits = len(str(num))

    temp = num
    total = 0

    while temp > 0:
        digit = temp % 10
        total += digit ** digits
        temp //= 10

    if total == num:
        return True
    else:
        return False

num = int(input("Enter a number: "))

print(armstrong(num))
# Out:
# Enter a number:  145
# False
